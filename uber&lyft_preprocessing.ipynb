# %%
#mount you google drive environment
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#modify path where you put your csv file on your PC
path = '/content/drive/MyDrive/Colab Notebooks/CSCE5300/project/Uber & Lyft Cab prices/'

# %%
#['weather.csv', 'cab_rides.csv']
f = ['uber-raw-data-janjune-15.csv']
df=pd.read_csv(path+'cab_rides.csv')

df
# Out:
#         distance cab_type  ...                            product_id          name
# 0           0.44     Lyft  ...                             lyft_line        Shared
# 1           0.44     Lyft  ...                          lyft_premier           Lux
# 2           0.44     Lyft  ...                                  lyft          Lyft
# 3           0.44     Lyft  ...                           lyft_luxsuv  Lux Black XL
# 4           0.44     Lyft  ...                             lyft_plus       Lyft XL
# ...          ...      ...  ...                                   ...           ...
# 693066      1.00     Uber  ...  6f72dfc5-27f1-42e8-84db-ccc7a75f6969        UberXL
# 693067      1.00     Uber  ...  55c66225-fbe7-4fd5-9072-eab1ece5e23e         UberX
# 693068      1.00     Uber  ...  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a          Taxi
# 693069      1.00     Uber  ...  6d318bcc-22a3-4af6-bddd-b409bfce1546     Black SUV
# ...

# %%
import re
def trunk_minisec(d):
  time_list = re.split('-| |:|\.', str(d))
  return time_list[0]+'-'+time_list[1]+'-'+time_list[2]+' '+time_list[3]+':'+time_list[4]+':'+time_list[5]

# %%
df['time_stamp'] = pd.to_datetime(df['time_stamp']).apply(lambda x: trunk_minisec(x))
df = df.drop(['id', 'product_id'], axis=1)

# %%
df.head()
# Out:
#    distance cab_type  ... surge_multiplier          name
# 0      0.44     Lyft  ...              1.0        Shared
# 1      0.44     Lyft  ...              1.0           Lux
# 2      0.44     Lyft  ...              1.0          Lyft
# 3      0.44     Lyft  ...              1.0  Lux Black XL
# 4      0.44     Lyft  ...              1.0       Lyft XL
#
# [5 rows x 8 columns]

# %%
df[df['distance'] == df['distance'].max()]
# Out:
#         distance cab_type  ... surge_multiplier       name
# 658723      7.86     Uber  ...              1.0      UberX
# 658724      7.86     Uber  ...              1.0      Black
# 658725      7.86     Uber  ...              1.0        WAV
# 658726      7.86     Uber  ...              1.0   UberPool
# 658727      7.86     Uber  ...              1.0       Taxi
# 658728      7.86     Uber  ...              1.0  Black SUV
# 658729      7.86     Uber  ...              1.0     UberXL
#
# [7 rows x 8 columns]
